# %% [markdown]
# ### Best Run cmd

# %%
uv run main.py \
  --disable_disentangle \
  --disable_meta \
  --disable_causal \
  --disable_curriculum \
  --disable_hgt \
  --data_dir Datasets_mini_v1\(1000\) --lasso_path Datasets_mini_v1\(1000\)/lasso_augmented_data.csv --seed 42
